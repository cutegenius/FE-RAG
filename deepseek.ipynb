# %%
from langchain_openai import ChatOpenAI
import os
deepseek_key=os.getenv("DEEPSEEK_API_KEY")
llm=ChatOpenAI(temperature=0.95,model="deepseek-chat",api_key=deepseek_key,base_url="https://api.deepseek.com")

# %%
import requests
import json
import os
newsapi_key=os.getenv("NewsAPI")
 
url_list = [
    f'https://newsapi.org/v2/everything?q=农林牧渔&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=基础化工&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=钢铁&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=有色金属&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=电子&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=家用电器&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=食品饮料&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=纺织服饰&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=轻工制造&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=医药生物&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=公用事业&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=交通运输&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=房地产&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=商贸零售&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=社会服务&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=综合&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=建筑材料&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=建筑装饰&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=电力设备&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=国防军工&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=计算机&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=传媒&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=通信&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=银行&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=非银金融&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=汽车&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=机械设备&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=煤炭&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=石油石化&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=环保&apiKey={newsapi_key}',
    f'https://newsapi.org/v2/everything?q=美容护理&apiKey={newsapi_key}'
]

# url_list = [
#     f'https://newsapi.org/v2/everything?q=石油&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=石化&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=煤炭&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=有色金属&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=电力&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=钢铁&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=基础化工&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=建筑建材&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=轻工制造&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=机械&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=电力设备及新能源&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=国防军工&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=汽车&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=商贸零售&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=旅游酒店教育&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=家电&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=纺织服装&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=医药&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=食品饮料&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=农林牧渔&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=银行保险证券多元金融&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=电子半导体消费电子&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=通信&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=计算机&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=传媒影视游戏出版等&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=业务多元化&apiKey={newsapi_key}',
#     f'https://newsapi.org/v2/everything?q=综合&apiKey={newsapi_key}'
# ]

content = []
for url in url_list:
    response = requests.get(url)
    if response.status_code == 200:  # 检查请求是否成功
        data = response.json()
        for article in data["articles"]:
            content.append(article["description"]) 
    else:
        print(f"请求失败：{url}，状态码：{response.status_code}")

print(content)
# Out:
# ['アメリカ内務省の海洋エネルギー管理局（BOEM）は、絶滅危惧種に指定されているライスクジラの生息域を通る船の速度を時速約18.5km以下に制限するよう求めていた勧告を撤回すると発表しました。', '1 名前：蚤の市 ★：2025/02/19(水) 06:47:24.53 ID:Pl6FM8sn9.net\n\n\n\n\n\n\n\nガソリン価格カルテル疑い\u3000公取委、長野石油商業組合に立ち入りhttps://t.co/980FNboHNW\u3000長野県内のガソリン価格は全国トップ級の高値で推移しており、住民が不当に割高な価格での購入を余儀な...', '長野県内のガソリンスタンド（GS）がカルテルを結んでいた疑いがあるとして、公正取引委員会は18日、独占禁止法違反（不当な取引制限）容疑で、同県石油商業組合（長野市）に立ち入り検査に入った。関係者への…', '似乎不只是川普政府，或是美國能源企業，甚至是歐洲的能源企業，都開始「Drill, baby, drill!」了？', '石油開採與環保聽起來方向相反，不過美國有石油公司近年積極發展碳捕捉技術，除了可以減少空氣中的二氧化碳，更可以用來提升採油效率。不過對此有環保組織認為最後只會增加碳排放。\nThe post 石油公司發展碳捕捉技術\u3000協助提升採油效率 appeared first on 香港 unwire.hk 玩生活．樂科技.', 'さて、一口に投資といってもいろいろなものがある。一番の王道は株式投資。そのほか、債券、不動産、石油、貴金属、最近ではFX、暗号資産なども流行している。変わったところではウイスキーやワインなどのお酒、美…', '長野県内でガソリン価格を不正に調整するカルテルを結んだ疑いで、公正取引委員会が、県石油商業組合に立ち入り検査を行ったことについて、武藤経済産業大臣は「事実であれば問題は大変大きい」と述べ、全国の石油組合などに対して法令順守体制の強化を求めていく考えを示しました。', '米WTI原油先物価格（原油価格）は今週に入り、1バレル＝65〜70ドルの間で推移している。レンジの下限が先週と比べて3ドル低下している。市場の需給緩和が嫌気され、原油価格は一時、65.22ドルと約2年ぶりの安値を付けた。\u3000まず、いつものように世界の原油市場の需給を巡る動き
# ...

# %%
#chain.invoke({"adjective":adjective, "content":content})

# %%
#pip install langchain_community

# %%
from langchain_community.vectorstores import FAISS

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
#pip install sentence-transformers

# %%
#pip install langchain-huggingface

# %%
embeddings_path="C:\\Users\\lenovo\\bge-large-zh-v1.5"
model_kwargs = {'trust_remote_code': True}
embeddings=HuggingFaceEmbeddings(model_name=embeddings_path,model_kwargs=model_kwargs)

# %%
#pip install faiss-gpu

# %%
#pip install faiss-cpu

# %%
vectorstore=FAISS.from_texts(
    content,
    embedding=embeddings
)

# %%
retriver=vectorstore.as_retriever()

result=retriver.invoke("电力行业怎么样")
print(result)
# Out:
# [Document(id='a96904a1-d91a-499b-bccb-a985925aa5fd', metadata={}, page_content='IT之家 2 月 18 日消息，第十五届中国国际清洁能源博览会（CEEC 2025）将于 2025 年 03 月 26 日 - 28 日在北京国家会议中心举行，期间将举办 30 多场重磅专题会议、40 多场新品发布会，以及国际交流活动等。在今日的新闻发布会上，中国电力企业联合会副秘书长刘永东在会上从四个方面介绍了我国能源电力行业的最新发展情况。刘永东表示，截至 2024 年底，我国可再生能源装机达到 18.89 亿千瓦，同比增长 25%，约占我国总装机的 56%，其中水电装机 4.36 亿千瓦，风电装机 5.21…'), Document(id='9d7c80ee-4e21-4726-aff6-34bfaa5f58e9', metadata={}, page_content='IT之家 2 月 18 日消息，第十五届中国国际清洁能源博览会（CEEC 2025）将于 2025 年 03 月 26 日 - 28 日在北京国家会议中心举行，期间将举办 30 多场重磅专题会议、40 多场新品发布会，以及国际交流活动等。在今日的新闻发布会上，中国电力企业联合会副秘书长刘永东在会上从四个方面介绍了我国能源电力行业的最新发展情况。刘永东表示，截至 2024 年底，我国可再生能源装机达到 18.89 亿千瓦，同比增长 25%，约占我国总装机的 56%，其中水电装机 4.36 亿千瓦，风电装机 5.21…'), Document(id='d213feb4-6a73-47ea-be5a-ee3e341c934b', metadata={}, page_content='IT之家 2 月 18 日消息，第十五届中国国际清洁能源博览会（CEEC 2025）将于 2025 年 03 月 26 日 - 28 日在北京国家会议中心举行，期间将举办 30 多场重磅专题会议、40 多场新品发布会，以及国际交流活动等。在今日的新闻发布会上，中国电力企业联合会副秘书长刘永东在会上从四个方面介绍了我国能源电力行业的最新发展情况。刘永东表示，截至 2024 年底，我国可再生能源装机达到 18.89 亿千瓦，同比增长 25%，约占我国总装机的 56
# ...

# %%
#pip install langchain_openai

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel,RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
import os
from operator import itemgetter
deepseek_key=os.getenv("DEEPSEEK_API_KEY")
llm=ChatOpenAI(temperature=0.95,model="deepseek-chat",api_key=deepseek_key,base_url="https://api.deepseek.com")
adjective=["石油","石化",
           "煤炭","有色金属","电力及公用事业","钢铁","基础化工","建筑建材","轻工制造","机械","电力设备及新能源","国防军工","汽车","商贸零售","消费者服务（如旅游、酒店、教育等）","家电","纺织服装","医药","食品饮料","农林牧渔",
           "银行非银行金融（保险、证券、多元金融等）","房地产"
,"交通运输"
,"电子（半导体、消费电子等）"
,"通信"
,"计算机"
,"传媒（影视、游戏、出版等）"
,"综合（业务多元化的企业）"
,"综合金融（部分版本可能单列）"]

template="""
"请根据以下新闻信息{context},和以下研报信息{report}回答问题：
给出对这些行业：{adjective}

问题：{question}
"""

prompt=ChatPromptTemplate.from_template(template)

outputParser=StrOutputParser()


chain = (
    {
        "context": itemgetter("question") | retriver,
        "report": itemgetter("question") | retriver2,
        "question": itemgetter("question"),
        "adjective": itemgetter("adjective"),
    }
    | prompt
    | llm
    | StrOutputParser()
)


result=chain.invoke({"question":"要投资什么行业并说明理由","adjective":adjective})
print("结果：",result)
# Out:
# 结果： 根据提供的新闻信息和国家政策导向，以下是建议投资的行业及其理由：
#
# ### 1. **电力设备及新能源**
#    - **理由**：国家正在大力发展新质生产力，并组建国家创业投资引导基金，带动地方资金和社会资本近1万亿元。新能源行业（如光伏、风电、储能等）是未来能源转型的核心方向，政策支持力度大，市场需求增长迅速，具有长期投资价值。
#
# ### 2. **电子（半导体、消费电子等）**
#    - **理由**：半导体和消费电子是科技创新的重要领域，尤其是半导体行业，国家正在大力推动自主可控的产业链建设。随着5G、人工智能、物联网等技术的普及，电子行业的需求将持续增长。
#
# ### 3. **医药**
#    - **理由**：医药行业是刚需行业，随着人口老龄化和健康意识的提升，医药需求将持续增长。国家也在推动医药创新和医疗体制改革，医药行业具有长期稳定的增长潜力。
#
# ### 4. **食品饮料**
#    - **理由**：食品饮料行业是典型的消费行业，国家正在推动消费品以旧换新政策，支持资金从去年的1500亿元增加到3000亿元。随着消费升级和居民收入水平的提高，食品饮料行业的市场需求将保持稳定增长。
#
# ### 5. **汽车**
#    - **理由**：汽车行业尤其是新能源汽车领域，受益于国家政策支持和环保趋势。随着新能源汽车技术的成熟和充电基础设施的完善，新能源汽车市场将迎来快速增长。
#
# ### 6. **银行非银行金融（保险、证券、多元金融等）**
#    - **理由**：金融行业是经济的核心，随着国家推动资本市场改革和金融开放，证券、保险等行业将受益于资本市场的活跃和金融创新的推进。
#
# ### 7. **房地产**
#    - **理由**：虽然房地产行业面临一定的调控压力，但国家也在推动房地产市场的稳定发展，尤其是在城市更新、保障性住房等领域，房地产行业仍有一定的投资机会。
#
# ### 8. **交通运输**
#    - **理由**：随着经济复苏和物流需求的增长，交通运输行业将受益于基础设施建设和物流行业的快速发展。
#
# ### 9. **国防军工**
# ...

# %%
#pip install selenium

# %%
#pip install pypdf

# %%
#pip install cryptography

# %%
from datetime import datetime
from selenium import webdriver
#from selenium.webdriver.common.action_chains import ActionChains #引入ActionChains鼠标操作类
#from selenium.webdriver.common.keys import Keys #引入keys类操作
import time
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
import re
import requests
import pandas as pd
import os

site_industry_report = r'http://data.eastmoney.com/report/industry.jshtml'

def filename_title_filter(text):
    text = text.replace(':', '')
    text = text.replace('/', '')
    text = text.replace("\\", '')
    text = text.replace('?', '')
    text = text.replace('"', '')
    text = text.replace('*', '')
    text = text.replace('|', '')
    text = text.replace('>', '')
    text = text.replace('<', '')
    return text

def filename_date_filter(text):
    return text.replace(':', '')

def scrape_industry(start_page = 1, scrape_page = 2, save_file=file_industry_report_link):#行业研报
    options = webdriver.ChromeOptions()
    #options.add_argument('headless')
    options.add_argument('--start-maximized')
    service = Service(r'C:\Users\lenovo\chromedriver-win64\chromedriver.exe')
    #driver = webdriver.Chrome(service=service)
    browser = webdriver.Chrome(service=service, options=options)#, chrome_options=options)# chrome_options=options)
    browser.get(site_industry_report)#打开网页
    time.sleep(3)

    ele = browser.find_element(By.ID,"change_time")
    select_ele = Select(ele)
    select_ele.select_by_value("2")

#    options = webdriver.ChromeOptions()
#    options.add_argument('headless')
#    browser = webdriver.Chrome(executable_path = r'D:\Download\chromedriver_win32\chromedriver.exe',  options=options)
#    browser = webdriver.Chrome(executable_path = r'C:\Users\l\AppData\Local\Google\Chrome\Application\chromedriver.exe', options=options)#, chrome_options=options)# chrome_options=options)
#    browser.get(site_stock_report)
#    time.sleep(3)
# 
    if scrape_page==None:
        total_page_text = WebDriverWait(browser, 5).until(lambda x: x.find_element(By.XPATH,"/html/body/div[1]/div[8]/div[2]/div[6]/div[1]/a[7]")).text
        total_page = int(total_page_text)
    else:
        total_page = scrape_page

    out = []
    with open(save_file, 'a+') as f:
        for page in range(start_page, total_page+1):
#            browser.get(site_industry_report)#打开网页
#            time.sleep(3)

            WebDriverWait(browser, 5).until(lambda x: x.find_element(By.XPATH,"//input[@id='gotopageindex']")).clear()
            browser.find_element(By.XPATH,"//input[@id='gotopageindex']").send_keys(page)
            #browser.find_element(By.XPATH,"//input[@value='确定']").click()
            submit_button = browser.find_element(By.CSS_SELECTOR, 'input.btn[value="确定"]')
            browser.execute_script("arguments[0].click();", submit_button)
            time.sleep(3)
            
            page_sourece = browser.page_source
            out.append(page_sourece)
            
            res_link_list = re.findall('infocode=(.*?)"', page_sourece)
            res_link_list2 = [ "http://data.eastmoney.com/report/zw_industry.jshtml?infocode=%s\n"%i for i in res_link_list] 
#            res_link_list = re.findall('encodeUrl=(.*?)"', page_sourece)
#            res_link_list2 = [ "http://data.eastmoney.com/report/zw_industry.jshtml?encodeUrl=%s\n"%i for i in res_link_list] 
#            print(res_link_list2[0])
            f.writelines(res_link_list2)
            strTime = time.strftime("%Y-%m-%d %H:%M:%S",time.localtime())
            print( '行业 第%s页 采集数目%s  %s'%(page, len(res_link_list2), strTime))
            if len(res_link_list) == 50 and page!= total_page:
                pass
            else:                
                print( '提示：第%s页 采集数目%s [数目不足] %s'%(page, len(res_link_list2), strTime))
    f.close()
    return out

def down_industry(start_line = 1, save_file=file_industry_report_link, sleep_sec=2):    
    report_lis = pd.Series(list(open(save_file))).dropna()
#    downloaded_str = downloaded.read()
    browsered = r'C:\Users\lenovo\Documents\industry browsered.txt'
#    downloaded =  r'D:\code\python\download2.txt'
#    browsered_str = open( browsered, 'r').read()
#    downloaded_str = open(downloaded, 'r').read()
    file_exist_counter = 0
    
    options = webdriver.ChromeOptions()
    #options.add_argument('headless')
    options.add_argument('--start-maximized')
    service = Service(r'C:\Users\lenovo\chromedriver-win64\chromedriver.exe')
    #driver = webdriver.Chrome(service=service)
    browser2 = webdriver.Chrome(service=service, options=options)

    for i in range(start_line, len(report_lis)):
        try:
            strTime = time.strftime("%Y-%m-%d %H:%M:%S",time.localtime())
            link = report_lis[i].replace('\n','')  
#            browsered_str = open( browsered, 'r').read()
            print('%s [行业] 开始于%s'%(i, start_line))
            if 1==2:
#            if (link in browsered_str) :
                print(i, '[已浏览] %s'%strTime)
            else:
                browser2.get(link)
                time.sleep(sleep_sec)
                page_sourece = browser2.page_source
#                report_title = re.findall('"title":"(.*?)"', page_sourece)[0]                
#                report_date = re.findall('"publishDate":"(.*?)"', page_sourece)[0]
#                report_broker = re.findall('"orgSName":"(.*?)"', page_sourece)[0]
#                report_author = re.findall('"researcher":"(.*?)"', page_sourece)[0]              
                
                
                report_date = re.findall('notice_date":"(.*?)"', page_sourece)[0]
                report_title = re.findall('"notice_title":"(.*?)"', page_sourece)[0]
#                stock_name = re.findall('"short_name":"(.*?)"', page_sourece)[0]
                report_author = re.findall('"researcher":"(.*?)"', page_sourece)[0]
                report_broker = re.findall('"source_sample_name":"(.*?)"', page_sourece)[0]                
#                /html[1]/body[1]/div[4]/div[2]/div[3]/div[1]/div[1]/h1[1]
#                report_title = browser2.find_element_by_xpath('/html[1]/body[1]/div[3]/div[1]/div[3]/div[1]/div[1]/div[1]/h1[1]').text
#                report_date = browser2.find_element_by_xpath('/html[1]/body[1]/div[3]/div[1]/div[3]/div[1]/div[1]/div[2]/span[2]').text
#                report_broker = browser2.find_element_by_xpath('/html[1]/body[1]/div[3]/div[1]/div[3]/div[1]/div[1]/div[2]/span[3]').text
#                report_author = browser2.find_element_by_xpath('/html[1]/body[1]/div[3]/div[1]/div[3]/div[1]/div[1]/div[2]/span[4]').text
                report_date = filename_date_filter(report_date)
                report_title = filename_title_filter(report_title)  
                filename = r"C:\Users\lenovo\Documents\industry report\%s %s %s %s.pdf"%(report_date, report_title, report_broker, report_author)
                
                with open(browsered, 'a+') as f3:
                    f3.write(link)
                if os.path.exists(filename):
                    print(i ,'[文件存在]  %s'%(strTime))
                    file_exist_counter +=1
    
                else:
#                    page_sourece = browser2.page_source
#                    match_pdf = re.findall("attachUrl":"(.*?)", page_sourece)[0]
#                    match_pdf = re.findall('pdf.(.*?)"', page_sourece)
                    match_pdf =re.findall('"attach_url":"(.*?)"', page_sourece)
#                    match_pdf  = re.findall('http://(.*?).pdf"|http://(.*?).PDF"', page_sourece)
#                    match_pdf2 = re.findall('http://(.*?).PDF"', page_sourece)
                    
#                    print(match_pdf)
                    if len(match_pdf) ==0:
                        print(i, '[无下载地址] %s'%strTime)
                    else:
#                        if match_pdf[0][0]!='':
#                            pdf_url = 'http://%s.pdf' %(match_pdf[0][0])
#                        else:
#                            pdf_url = 'http://%s.PDF' %(match_pdf[0][1])
#                        pdf_url = "http://pdf.%s"% match_pdf[0]
#                        print("下载地址", pdf_url)                        
                        r = requests.get(match_pdf[0]) 
                        with open(filename, 'wb') as f:
                            f.write(r.content)                            
                        print(i , '[完成下载]  %s'%(strTime))
                        time.sleep(0.01)
        except Exception as e:
            print(e)
    browser2.quit()

def daily_task_ind( scrape_page=4, start_line=0):
    datetime_str = datetime.now().strftime(datetime.now().strftime("%Y-%m-%d %H-%M-%S"))
    fn_industry = r'C:\Users\lenovo\Documents\report down url\ind report url %s.txt'%datetime_str
    print(fn_industry)
    scrape_industry(scrape_page = scrape_page, save_file = fn_industry)
    down_industry(save_file = fn_industry, start_line = start_line)

daily_task_ind(scrape_page=None)

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
loader=PyPDFDirectoryLoader(r'C:\Users\lenovo\Documents\industry report')
docs=loader.load()
print(docs)
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 11 0 (offset 0)
# Ignoring wrong pointing object 13 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 40 0 (offset 0)
# Ignoring wrong pointing object 42 0 (offset 0)
# Ignoring wrong pointing object 44 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
embeddings_path="C:\\Users\\lenovo\\bge-large-zh-v1.5"
model_kwargs = {'trust_remote_code': True}
embeddings=HuggingFaceEmbeddings(model_name=embeddings_path,model_kwargs=model_kwargs)
vectorStoreDB=FAISS.from_documents(docs,embedding=embeddings)

retriever2=vectorStoreDB.as_retriever(
    search_type='mmr',
    search_kwargs={"k":60}
)

# %%
import akshare as ak
import numpy as np
industry_code=[
    "801010","801030","801040",
"801050","801080","801110","801120","801130","801140","801150",
"801160","801170","801180",
"801200","801210","801230","801710",
"801720","801730","801740","801750",
"801760","801770","801780",
"801790","801880","801890","801950","801960"
,"801970","801980"
]
def macd(col,short=12,long=26,mid=9):
    DIF=col.ewm(span=short, adjust=False).mean()-col.ewm(span=long, adjust=False).mean()
    DEA=DIF.ewm(span=mid, adjust=False).mean()
    MACD=(DIF-DEA)*2
    return MACD

def rsi(col, window=14):
    delta = col.diff(1)  # 计算价格变动
    gain = delta.where(delta > 0, 0)  # 分离涨幅
    loss = -delta.where(delta < 0, 0)  # 分离跌幅（取绝对值）

    # 计算初始平均（前window天简单平均）
    avg_gain = gain.rolling(window=window).mean()
    avg_loss = loss.rolling(window=window).mean()

    # 计算后续平滑平均（Wilder's Smoothing）
    for i in range(window, len(gain)):
        avg_gain[i] = (avg_gain[i-1] * (window-1) + gain[i]) / window
        avg_loss[i] = (avg_loss[i-1] * (window-1) + loss[i]) / window

    # 计算RS和RSI
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def boll(col,n=20, k=2):
        # 计算移动平均线(中轨)
        middle = col.rolling(window=n).mean()
        
        # 计算标准差
        std = col.rolling(window=n).std()
        
        # 计算上轨和下轨
        upper = middle + k * std
        lower = middle - k * std
        
        # 计算因子值：价格在布林带中的相对位置
        boll= np.clip((col - lower) / (upper - lower),0,1)
        return boll

for code in industry_code: 
    index_hist_sw_df = ak.index_hist_sw(symbol=code, period="day")
    print(index_hist_sw_df)
    index_hist_sw_df["MA_5"] = index_hist_sw_df["收盘"].pct_change(periods=5) 
    index_hist_sw_df["MA_20"] = index_hist_sw_df["收盘"].pct_change(periods=20) 
    index_hist_sw_df["MA_60"] = index_hist_sw_df["收盘"].pct_change(periods=60) 
    index_hist_sw_df["MA_120"] = index_hist_sw_df["收盘"].pct_change(periods=120) 
    index_hist_sw_df["EMA_5"] = index_hist_sw_df["收盘"].ewm(span=5, adjust=False).mean()
    index_hist_sw_df["EMA_20"] = index_hist_sw_df["收盘"].ewm(span=20, adjust=False).mean()
    index_hist_sw_df["EMA_60"] = index_hist_sw_df["收盘"].ewm(span=60, adjust=False).mean()
    index_hist_sw_df["EMA_120"] = index_hist_sw_df["收盘"].ewm(span=120, adjust=False).mean()
    index_hist_sw_df["MACD"] = macd(index_hist_sw_df["收盘"])
    index_hist_sw_df["RSI"] = rsi(index_hist_sw_df["收盘"])
    index_hist_sw_df["BOLL"] = boll(index_hist_sw_df["收盘"])
    print(index_hist_sw_df)
    index_hist_sw_df.to_csv(rf"C:\Users\lenovo\Documents\industry price\{code}.csv", index=False, encoding="utf-8-sig")

# %%
from langchain_community.document_loaders import DirectoryLoader
loader3 = DirectoryLoader('C:/Users/lenovo/Documents/industry price/',glob="**/*.csv")
 
docs3 = loader3.load()
 
print(len(docs))

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
embeddings_path="C:\\Users\\lenovo\\bge-large-zh-v1.5"
model_kwargs = {'trust_remote_code': True}
embeddings=HuggingFaceEmbeddings(model_name=embeddings_path,model_kwargs=model_kwargs)
vectorStoreDB3=FAISS.from_documents(docs3,embedding=embeddings)

retriever3=vectorStoreDB3.as_retriever(
    search_type='mmr',
    search_kwargs={"k":60}
)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel,RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI
import os
from operator import itemgetter
deepseek_key=os.getenv("DEEPSEEK_API_KEY")
llm=ChatOpenAI(temperature=0.95,model="deepseek-chat",api_key=deepseek_key,base_url="https://api.deepseek.com")
# adjective=["石油","石化",
#            "煤炭","有色金属","电力及公用事业","钢铁","基础化工","建筑建材","轻工制造","机械","电力设备及新能源","国防军工","汽车","商贸零售","消费者服务（如旅游、酒店、教育等）","家电","纺织服装","医药","食品饮料","农林牧渔",
#            "银行非银行金融（保险、证券、多元金融等）","房地产"
# ,"交通运输"
# ,"电子（半导体、消费电子等）"
# ,"通信"
# ,"计算机"
# ,"传媒（影视、游戏、出版等）"
# ,"综合（业务多元化的企业）"
# ,"综合金融（部分版本可能单列）"]
adjective=[
    "农林牧渔","基础化工","钢铁","有色金属",
"电子","家用电器","食品饮料","纺织服饰",
"轻工制造","医药生物","公用事业","交通运输",
"房地产","商贸零售","社会服务","综合",
"建筑材料","建筑装饰","电力设备","国防军工",
"计算机","传媒","通信","银行","非银金融",
"汽车","机械设备","煤炭","石油石化","环保","美容护理"
]

industry_map={
    "801010":"农林牧渔",
    "801030":"基础化工",
    "801040":"钢铁",
    "801050":"有色金属",
    "801080":"电子",
    "801110":"家用电器",
    "801120":"食品饮料",
    "801130":"纺织服饰",
    "801140":"轻工制造",
    "801150":"医药生物",
    "801160":"公用事业",
    "801170":"交通运输",
    "801180":"房地产",
    "801200":"商贸零售",
    "801210":"社会服务",
    "801230":"综合",
    "801710":"建筑材料",
    "801720":"建筑装饰",
    "801730":"电力设备",
    "801740":"国防军工",
    "801750":"计算机",
    "801760":"传媒",
    "801770":"通信",
    "801780":"银行",
    "801790":"非银金融",
    "801880":"汽车",
    "801890":"机械设备",
    "801950":"煤炭",
    "801960":"石油石化",
    "801970":"环保",
    "801980":"美容护理"
    }

template="""
"请根据以下新闻信息{context}和以下研报信息{report}和行情数据{price}回答问题：
行业：{adjective}
行业和代码的对应关系:{industry_map}
问题：{question}
"""

prompt=ChatPromptTemplate.from_template(template)

outputParser=StrOutputParser()


chain = (
    {
        "context": itemgetter("question") | retriver,
        "report": itemgetter("question") | retriever2,
        "price": itemgetter("question") | retriever3,
        "question": itemgetter("question"),
        "adjective": itemgetter("adjective"),
    }
    | prompt
    | llm
    | StrOutputParser()
)


result=chain.invoke({"question":"要投资什么行业并说明理由","adjective":adjective})
print("结果：",result)
